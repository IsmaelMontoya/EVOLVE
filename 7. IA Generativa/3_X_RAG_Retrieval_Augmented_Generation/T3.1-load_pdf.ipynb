# %%
from dotenv import load_dotenv
import os

# %%
load_dotenv()
API_KEY = os.getenv("GEMINI_API_KEY")

# API key de Gemini
# API_KEY = userdata.get('GEMINI_API_KEY')

# %%
from langchain_google_genai import ChatGoogleGenerativeAI
from langchain_core.prompts import ChatPromptTemplate, SystemMessagePromptTemplate, HumanMessagePromptTemplate
from langchain_core.messages import HumanMessage, AIMessage

from pydantic import BaseModel, Field

from langchain_community.document_loaders import PyPDFLoader
# Out:
# c:\Users\rt01284\GITHUB\Evolve-MDS-2025-Oct-IAGen\.venv\Lib\site-packages\langchain_core\_api\deprecation.py:26: UserWarning: Core Pydantic V1 functionality isn't compatible with Python 3.14 or greater.
#   from pydantic.v1.fields import FieldInfo as FieldInfoV1

# %%
ruta = "../data/Montaje_de_un_Motor_Eléctrico_Básico.pdf"

loader = PyPDFLoader(ruta)

pages = loader.load()

print(dir(pages[0]))

for i, pages in enumerate(pages):
    print(f"=== Pagina {i+1} ===")
    print(f"Contenido {pages.page_content}")
# Out:
# ['__abstractmethods__', '__annotate_func__', '__annotations__', '__annotations_cache__', '__class__', '__class_getitem__', '__class_vars__', '__copy__', '__deepcopy__', '__delattr__', '__dict__', '__dir__', '__doc__', '__eq__', '__fields__', '__fields_set__', '__firstlineno__', '__format__', '__ge__', '__get_pydantic_core_schema__', '__get_pydantic_json_schema__', '__getattr__', '__getattribute__', '__getstate__', '__gt__', '__hash__', '__init__', '__init_subclass__', '__iter__', '__le__', '__lt__', '__module__', '__ne__', '__new__', '__pretty__', '__private_attributes__', '__pydantic_complete__', '__pydantic_computed_fields__', '__pydantic_core_schema__', '__pydantic_custom_init__', '__pydantic_decorators__', '__pydantic_extra__', '__pydantic_fields__', '__pydantic_fields_set__', '__pydantic_generic_metadata__', '__pydantic_init_subclass__', '__pydantic_on_complete__', '__pydantic_parent_namespace__', '__pydantic_post_init__', '__pydantic_private__', '__pydantic_root_model__', '__pydantic_serializer__', '__pydantic_setattr_handlers__', '__pydantic_validator__', '__reduce__', '__reduce_ex__', '__replace__', '__repr__', '__repr_args__', '__repr_name__', '__repr_recursion__', '__repr_str__', '__rich_repr__', '__setattr__', '__setstate__', '__signature__', '__sizeof__', '__slots__', '__static_attributes__', '__str__', '__subclasshook__', '__weakref__', '_abc_impl', '_calculate_keys', '_copy_and_set_values', '_get_value', '_iter', '_setattr_handler', 'construct', 'copy', 'dict', 'from_orm', 'get_lc_namespace', 'id', 'is_lc_serializable', 'json', 'lc_attributes', 'lc_id', 'lc_secrets', 'metadata', 'model_computed_fields', 'model_config', 'model_construct', 'model_copy', 'model_dump', 'model_dump_json', 'model_extra', 'model_fields', 'model_fields_set', 'model_json_schema', 'model_parametrized_name', 'model_post_init', 'model_rebuild', 'model_validate', 'model_validate_json', 'model_validate_strings', 'page_content', 'parse_file', 'parse_obj', 'parse_raw', 'schema', 'schema_json', 'to_json', 'to_json_not_implemented', 'type', 'update_forward_refs', 'validate']
# === Pagina 1 ===
# Contenido 1. Materiales Necesarios:
# Para este proyecto, necesitarás los siguientes materiales:
# Componentes:
# • Estator: Bobina de cobre esmaltado, 1 m de longitud.
# • Rotor: Eje de acero (con diámetro de 5 mm y largo de 50 mm).
# • Imanes permanentes: 2 imanes de neodimio (dimensiones: 25 mm x 5 mm).
# • Escobillas de carbón: 2 piezas.
# • Carcasa del motor: 1 carcasa metálica con rosca para montaje (material de
# aluminio).
# • Colector: Commutador de cobre (típico para motores de corriente continua).
# • Soportes para el rotor: 2 cojinetes de acero.
# • Cables eléctricos: 2 cables de 1 metro cada uno (uno positivo y uno negativo).
# • Tornillos y tuercas: Para fijar las piezas entre sí.
# Herramientas:
# • Destornilladores (Phillips y plano).
# • Pistola de soldar (o soldador eléctrico).
# • Multímetro (para medición de corriente y resistencia).
# • Cinta aislante.
# • Prensa para ensamblaje de rodamientos.
# • Alicates.
#
# 2. Preparación:
# 2.1. Preparación de las piezas:
# 1. Estator: Si la bobina de cobre no está lista, procede a enrollar el cable en la forma
# adecuada (idealmente 100 vueltas). La bobina debe ajustarse al tamaño del
# hueco del estator.
# 2. Rotor: Inspecciona el eje de acero para verificar que no tenga imperfecciones. Si
# es necesario, límpialo con un trapo seco.
# 3. Imanes permanentes: Verifica que los imanes estén bien alineados y sin roturas.
# Los imanes deben tener polos opuestos que coincidan con las ranuras del rotor.
# 2.2. Preparación de herramientas:
# Asegúrate de tener todas las herramientas organizadas, especialmente el soldador, que
# se utilizará para conectar las escobillas y los cables.
# === Pagina 2 ===
# Contenido 3. Montaje del Motor Eléctrico:
# 3.1. Instalación del Estator:
# 1. Coloca la bobina de cobre en el estator. Deberás insertar la bobina en el espacio
# que tiene la carcasa del motor, de manera que quede ajustada.
# 2. Fijación: Usa tornillos pequeños o clips para mantener la bobina fija dentro de la
# carcasa del estator. Asegúrate de que no se mueva o pueda salirse.
# 3.2. Montaje del Rotor:
# 1. Coloca los cojinetes en los extremos del eje del rotor. Los cojinetes ayudarán a
# mantener el rotor girando libremente dentro de la carcasa.
# 2. Fijación del rotor: Inserta el rotor en la carcasa del motor, asegurándote de que
# encaje perfectamente en los cojinetes. El rotor debe girar sin fricción.
# 3.3. Instalación de los Imanes:
# 1. Coloca los imanes de neodimio en las ranuras del rotor. Estos imanes deben
# tener polos opuestos, como mencionamos antes.
# 2. Alineación: Los imanes deben estar colocados de tal forma que su campo
# magnético interactúe de manera eficiente con el campo magnético generado por
# el estator. La orientación de los imanes es crítica para la eficiencia del motor.
# 3.4. Conexión del Colector y las Escobillas:
# 1. Montaje del colector: Coloca el colector en el extremo del rotor. Este
# componente servirá para conectar el rotor con las escobillas.
# 2. Escobillas de carbón: Coloca las escobillas en las ranuras diseñadas para ello
# dentro de la carcasa del motor. Las escobillas deben hacer contacto con el
# colector, permitiendo que la corriente fluya a través del rotor.
# 3.5. Conexión Eléctrica:
# 1. Soldadura de cables: Con la pistola de soldar, conecta los cables a las
# escobillas, asegurándote de que no haya cortocircuitos. Un cable será para la
# entrada de corriente positiva y el otro para la corriente negativa.
# 2. Aislado de conexiones: Utiliza cinta aislante para proteger las conexiones,
# evitando que toquen partes metálicas.
#
# 4. Montaje de la Carcasa:
# 1. Fijación de la carcasa: Coloca la carcasa externa del motor y asegúrate de que
# quede completamente cerrada. Usa tornillos para atornillar las piezas metálicas y
# asegurar que el motor no se desarme.
# 2. Prueba de rotación: Gira el eje del rotor a mano para asegurarte de que el
# movimiento sea suave y libre de fricción.
# === Pagina 3 ===
# Contenido 5. Pruebas y Ajustes:
# 5.1. Medición de Continuidad:
# 1. Revisa las conexiones eléctricas con un multímetro para asegurarte de que no
# haya fallos de continuidad en el circuito.
# 5.2. Prueba de Funcionamiento:
# 1. Conecta el motor a una fuente de energía (batería o fuente de corriente
# continua).
# 2. Observa el giro del rotor: El motor debe comenzar a girar al recibir corriente
# eléctrica.
# 3. Ajuste de escobillas: Si el motor no gira suavemente, ajusta las escobillas de
# manera que hagan mejor contacto con el colector.
# 5.3. Verificación de Eficiencia:
# 1. Mide el voltaje y la corriente utilizando el multímetro mientras el motor está
# funcionando. Esto te permitirá verificar si el motor está funcionando dentro de los
# parámetros de diseño.
# 2. Asegúrate de que el motor no se sobrecaliente. Si lo hace, detén la prueba y
# revisa las conexiones eléctricas o el estado de las escobillas.
#
# 6. Mantenimiento:
# 1. Limpieza: Una vez que el motor esté en funcionamiento, es importante limpiar la
# carcasa regularmente para evitar la acumulación de polvo.
# 2. Reemplazo de escobillas: Si el motor empieza a fallar, revisa las escobillas y
# reemplázalas si están muy desgastadas.
# 3. Verificación de conexiones eléctricas: Asegúrate de que las conexiones de los
# cables se mantengan bien ajustadas.
