# %%
from langchain_google_genai import GoogleGenerativeAIEmbeddings

from langchain_huggingface.embeddings import HuggingFaceEmbeddings

from langchain_core.prompts import ChatPromptTemplate, SystemMessagePromptTemplate, HumanMessagePromptTemplate
from langchain_core.messages import HumanMessage, AIMessage

from pydantic import BaseModel, Field

from langchain_community.document_loaders import PyPDFDirectoryLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter

from langchain_chroma import Chroma

# %%
embeddings = HuggingFaceEmbeddings(
    model_name="sentence-transformers/all-MiniLM-L6-v2"
)
# Out:
# Loading weights:   0%|          | 0/103 [00:00<?, ?it/s]
# BertModel LOAD REPORT from: sentence-transformers/all-MiniLM-L6-v2
# Key                     | Status     |  |
# ------------------------+------------+--+-
# embeddings.position_ids | UNEXPECTED |  |
#
# Notes:
# - UNEXPECTED	:can be ignored when loading from different task/architecture; not ok if you expect identical arch.

# %%
vectorstore = Chroma(
    embedding_function=embeddings,
    persist_directory="../data/chroma_db"
)

# %%
retriever = vectorstore.as_retriever(search_type="similarity", search_kwargs={"k": 1})

# %%
consulta = "Cuanto salario percibe DANIEL ALEJANDRO RÍOS MARTÍNEZ:"

resultados = retriever.invoke(consulta)

print("Top 1:\n")
for i, doc in enumerate(resultados, start=1):
    print(f"Contenido: {doc.page_content}")
    print(f"Metadatos: {doc.metadata}")
# Out:
# Top 1:
#
# Contenido: CONTRATO DE TRABAJO POR TIEMPO
# INDETERMINADO
# QUE CELEBRAN POR UNA PARTE la empresa TECNOLOGÍAS AURORA IBERIA, S.L., y POR LA OTRA el
# trabajador DANIEL ALEJANDRO RÍOS MARTÍNEZ, al tenor de las siguientes declaraciones y cláusulas:
# I. DATOS DE IDENTIFICACIÓN DE LAS PARTES
# 1. Empleador
# Razón social: TECNOLOGÍAS AURORA IBERIA, S.L.
# CIF: B-91827364
# Domicilio social: Calle del Progreso nº 145, Piso 3, Oficina 7, 28037, Madrid, España.
# Actividad económica: Desarrollo de software, analítica de datos, servicios de inteligencia
# artificial, integración de sistemas y consultoría tecnológica.
# Representante legal: Laura Beatriz Mendoza Ortega.
# Cargo del representante: Directora General.
# Documento de identidad: DNI 45873219-Z.
# 2. Trabajador
# Nombre completo: Daniel Alejandro Ríos Martínez.
# Documento de identidad: DNI 73498126-P .
# Nacionalidad: Española.
# Fecha de nacimiento: 14 de marzo de 1991.
# Estado civil: Soltero.
# Domicilio: Avenida de las Encinas nº 22, Bajo B, 28935, Móstoles, Madrid, España.
# Metadatos: {'creationdate': '', 'page_label': '1', 'creator': 'ChatGPT', 'source': '..\\data\\contratos_laborales\\Contrato Laboral Individual I.pdf', 'producer': 'WeasyPrint 65.1', 'total_pages': 3, 'author': 'ChatGPT Canvas', 'page': 0, 'title': 'Contrato Laboral Individual'}
