# %% [markdown]
# # Titulo
#
# ## Subtitulo
#
# Listas
#
# * 1
# * 2
# * 2
#
# **Negrita** y *cursiva*

# %% [markdown]
# ## ENTORNO
# **Crear entorno**
#
# * mkdir evolve_env
#
# **Ir al repositorio creado y crearlo**
#
# * py -m venv venv
#
# **Activarlo**
#
# * .\venv\Scripts\Activate

# %% [markdown]
# ## Instalaciones
#
# * python -m pip install --upgrade pip
# * pip install numpy pandas
# * pip install seaborn matplotlib
#
# Kernel que ejecuta
# * pip install ipykernel
#
# **Registramos el entorno como kernel**
# * python -m ipykernel install --user --name evolve_env --display-name "Python (evolve_env)"
#
#
#
# ## Requirements
#
# * pip freeze > requirements.txt

# %% [markdown]
# import numpy as np
# import pandas as pd
#
# print("NumPy version:", np.__version__)
# print("Pandas version:", pd.__version__)

# %%
import numpy as np
import pandas as pd

print("NumPy version:", np.__version__)
print("Pandas version:", pd.__version__)

import sys
print(sys.executable)
# Out:
# NumPy version: 2.4.2
# Pandas version: 3.0.0
# e:\EVOLVE\PYTHON\evolve_env\venv\Scripts\python.exe
