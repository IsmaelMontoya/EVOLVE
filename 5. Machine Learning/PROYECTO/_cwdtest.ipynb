# %%
import os
print('CWD:', os.getcwd())
print('pkl exists:', os.path.exists('online_retail.pkl'))
print('files:', [f for f in os.listdir('.') if f.endswith('.pkl') or f.endswith('.ipynb')][:5])
# Out:
# CWD: /sessions/happy-serene-fermi/mnt/EVOLVE/5. Machine Learning/PROYECTO
# pkl exists: True
# files: ['Modelo_Recompra_Online_Retail.ipynb', '_cwdtest.ipynb']
